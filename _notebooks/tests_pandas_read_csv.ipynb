# %%
### READ CSV WITH PANDAS
### cf : https://chrisalbon.com/python/data_wrangling/pandas_dataframe_importing_csv/
import pandas as pd
from pprint import pprint

# %%
### uploaded file can be retrieved from form or parser 
uploaded_file = "tests_jupyter/2016_codes_postaux_population.csv"

# %%
### read csv / can take n first rows as header
## header : either 
# - None : no header at all
# - 0 : first row
# - list : [<row_index>, <row_index>, ...]

df = pd.read_csv(uploaded_file, header=0)

# %%
print df.sample(2)
# Out:
#       Code_postal Nom_commune_plus_peuplee Libelle_acheminement Ligne_5  \
# 3395        29700                 PLOMELIN             PLOMELIN     NaN
# 3492        32330                  GONDRIN              GONDRIN     NaN
#
#       latitude_avg  longitude_avg  Population  Nombre_communes_INSEE
# 3395     47.951243      -4.167165      8015.0                      2
# 3492     43.885410       0.252284      2739.0                      5

# %%
print df.sample(2)
# Out:
#       Code_postal Nom_commune_plus_peuplee Libelle_acheminement Ligne_5  \
# 5657        98762                   ARUTUA              NIUTAHI  ARUTUA
# 3250        25120                   MAICHE               MAICHE     NaN
#
#       latitude_avg  longitude_avg  Population  Nombre_communes_INSEE
# 5657           NaN            NaN         NaN                      1
# 3250     47.255421       6.774975      5698.0                      8

# %%
### get columns names
print list(df)
# Out:
# ['Code_postal', 'Nom_commune_plus_peuplee', 'Libelle_acheminement', 'Ligne_5', 'latitude_avg', 'longitude_avg', 'Population', 'Nombre_communes_INSEE']

# %%
### DF to JSON
pprint( df.sample(1).to_json() )
# Out:
# '{"Code_postal":{"1542":53160},"Nom_commune_plus_peuplee":{"1542":"BAIS"},"Libelle_acheminement":{"1542":"BAIS"},"Ligne_5":{"1542":null},"latitude_avg":{"1542":48.2481576425},"longitude_avg":{"1542":-0.3214726235},"Population":{"1542":5175.0},"Nombre_communes_INSEE":{"1542":10}}'

# %%
### DF to DICT
pprint( df.head(3).to_dict() )
# Out:
# {'Code_postal': {0: 1190, 1: 1200, 2: 1220},
#  'Libelle_acheminement': {0: 'PONT DE VAUX',
#                           1: 'BELLEGARDE SUR VALSERINE',
#                           2: 'DIVONNE LES BAINS'},
#  'Ligne_5': {0: nan, 1: nan, 2: nan},
#  'Nom_commune_plus_peuplee': {0: 'PONT DE VAUX',
#                               1: 'BELLEGARDE SUR VALSERINE',
#                               2: 'DIVONNE LES BAINS'},
#  'Nombre_communes_INSEE': {0: 12, 1: 14, 2: 3},
#  'Population': {0: 10114.0, 1: 28231.0, 2: 10601.0},
#  'latitude_avg': {0: 46.424627845111893,
#                   1: 46.116552211224295,
#                   2: 46.338259380222794},
#  'longitude_avg': {0: 4.9585619198112099,
#                    1: 5.8054256129029111,
#                    2: 6.11570959731743}}

# %%
df.to_dict(orient="list")
# Out:
# {'Code_postal': [1190,
#   1200,
#   1220,
#   1230,
#   1240,
#   1250,
#   1260,
#   1330,
#   1340,
#   1350,
#   1370,
#   1390,
#   1410,
#   1450,
#   1470,
#   1680,
#   1700,
#   1800,
#   1960,
#   2110,
#   2170,
#   2200,
#   2210,
#   2220,
#   2230,
#   2250,
#   2290,
#   2340,
#   2360,
#   2390,
#   2410,
#   2420,
#   2430,
#   2450,
#   2480,
#   2490,
#   2520,
#   2570,
#   2580,
#   2590,
#   2610,
#   2650,
#   2670,
#   2700,
#   2790,
#   2810,
#   2850,
#   2870,
#   2880,
#   3100,
#   3120,
#   3130,
#   3160,
#   3190,
#   3200,
#   3220,
#   3240,
#   3250,
#   3260,
#   3270,
#   3300,
#   3310,
#   3340,
#   3350,
#   3380,
#   3400,
#   3410,
#   3450,
#   3510,
#   3630,
#   3800,
#   4000,
#   4120,
#   4140,
#   4190,
#   4220,
#   4230,
#   4290,
#   4300,
#   4310,
#   4330,
#   4340,
#   4410,
#   4530,
#   4600,
#   4660,
#   4700,
#   4860,
#   4870,
#   5120,
#   5140,
#   5150,
#   5170,
#   5190,
#   5220,
#   5250,
#   5300,
#   5310,
# ...
