# %%
import pandas as pd
from pprint import pprint, pformat

# %%
uploaded_file_pipe = 'export_openscraper_5aa3de630a828651b2ebfe3e.csv'
uploaded_file_comma = '2016_codes_postaux_population.csv'

# %%
df = pd.read_csv(uploaded_file_comma, sep=',')
print (df.head(3))
# Out:
#    Code_postal  Nom_commune_plus_peuplee      Libelle_acheminement Ligne_5  \
# 0         1190              PONT DE VAUX              PONT DE VAUX     NaN
# 1         1200  BELLEGARDE SUR VALSERINE  BELLEGARDE SUR VALSERINE     NaN
# 2         1220         DIVONNE LES BAINS         DIVONNE LES BAINS     NaN
#
#    latitude_avg  longitude_avg  Population  Nombre_communes_INSEE
# 0     46.424628       4.958562     10114.0                     12
# 1     46.116552       5.805426     28231.0                     14
# 2     46.338259       6.115710     10601.0                      3

# %%
df = pd.read_csv(uploaded_file_pipe, sep='|')
print (df.head(3))
# Out:
#   spider_name                                           link_src  \
# 0     Apriles  http://www.apriles.net/index.php?option=com_so...
# 1     Apriles  http://www.apriles.net/index.php?option=com_so...
# 2     Apriles  http://www.apriles.net/index.php?option=com_so...
#
#                                            link_data  \
# 0  http://www.apriles.net/index.php?option=com_so...
# 1  http://www.apriles.net/index.php?option=com_so...
# 2  http://www.apriles.net/index.php?option=com_so...
#
#                                        fiche contact  \
# 0  82 avenue Jean Jaurès Directrice du pole Mail:...
# 1  Lien internet: Mail: 72 Rue Président Wilson 4...
# 2  Lien internet: 44100 Nantes Directrice, Pôle é...
#
#                                       date du projet  \
# 0  • APAJH • Association Charles de Foucauld Cons...
# 1  - Proposer des fruits et légumes frais de sais...
# 2  Etat (aides à la pierre), Région Pays-de-la-Lo...
#
# ...

# %%
df = df.dropna(how="all")
print (df.head(3))
# Out:
#   spider_name                                           link_src  \
# 0     Apriles  http://www.apriles.net/index.php?option=com_so...
# 1     Apriles  http://www.apriles.net/index.php?option=com_so...
# 2     Apriles  http://www.apriles.net/index.php?option=com_so...
#
#                                            link_data  \
# 0  http://www.apriles.net/index.php?option=com_so...
# 1  http://www.apriles.net/index.php?option=com_so...
# 2  http://www.apriles.net/index.php?option=com_so...
#
#                                        fiche contact  \
# 0  82 avenue Jean Jaurès Directrice du pole Mail:...
# 1  Lien internet: Mail: 72 Rue Président Wilson 4...
# 2  Lien internet: 44100 Nantes Directrice, Pôle é...
#
#                                       date du projet  \
# 0  • APAJH • Association Charles de Foucauld Cons...
# 1  - Proposer des fruits et légumes frais de sais...
# 2  Etat (aides à la pierre), Région Pays-de-la-Lo...
#
# ...

# %%
# df_col_dict = df.to_dict(orient="list")
df_col_dict = df.to_dict(orient='records')
df.head(5).to_dict(orient='records')
# Out:
# [{'SIRET': nan,
#   'adresse du projet': nan,
#   'auteur': 'http://www.apriles.net/images/stories/CentreparentalMigennesA.jpeg',
#   'date du projet': '\xe2\x80\xa2 APAJH \xe2\x80\xa2 Association Charles de Foucauld Conseil d\xc3\xa9partemental (ASE, PMI) \xe2\x80\xa2 Maison D\xc3\xa9partementale des Personnes handicap\xc3\xa9es (SAVS-SAMSA) \xe2\x80\xa2 Croix-Rouge, b\xc3\xa9n\xc3\xa9voles',
#   'donn\xc3\xa9es \xc3\xa9conomiques': "Gouvernance, partenariats institutionnels Vie en \xc3\xa9tablissement Int\xc3\xa9gration Parentalit\xc3\xa9 Lutte contre l'exclusion sociale Protection de l'enfance Nouvelles pratiques professionnelles Diagnostic partag\xc3\xa9",
#   'fiche contact': '82 avenue Jean Jaur\xc3\xa8s Directrice du pole Mail: Centre parental de Migennes - Croix rouge fran\xc3\xa7aise 89400 Migennes Tel: 03 86 92 37 90',
#   'image(s) du projet': nan,
#   'link_data': 'http://www.apriles.net/index.php?option=com_sobi2&sobi2Task=sobi2Details&catid=5&sobi2Id=1637&Itemid=95',
# ...
